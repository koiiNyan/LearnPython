# %%
import pandas as pd

# %%
data = pd.read_csv(
    open('stations.csv', 'r', encoding='cp1251'),
    sep=';'
)

# %%
data.head()
# Out:
#    ID                                               Name  Longitude_WGS84  \
# 0  65      «Бескудниково», Дмитровское шоссе (от центра)        37.548106
# 1  66  «Баскетбольная школа», Дубнинская улица (от це...        37.557747
# 2  67         «Д/к Юность», Дубнинская улица (от центра)        37.557714
# 3  68         «Мкр. Дубки», Дубнинская улица (от центра)        37.557680
# 4  69         «Ин-т Стали», Дубнинская улица (от центра)        37.557621
#
#    Latitude_WGS84             Street                          AdmArea  \
# 0       55.874340  Дмитровское шоссе  Северный административный округ
# 1       55.880612   Дубнинская улица  Северный административный округ
# 2       55.884081   Дубнинская улица  Северный административный округ
# 3       55.887618   Дубнинская улица  Северный административный округ
# 4       55.892287   Дубнинская улица  Северный административный округ
#
#                    District                   RouteNumbers  \
# ...

# %%
data[data['District']=='район Митино'].groupby('Street').size().reset_index().sort_values(0, ascending=False)
# Out:
#                                            Street   0
# 14                                 улица Кулакова  17
# 16                         улица Маршала Катукова  15
# 13                              улица Исаковского  14
# 8                                Таллинская улица  13
# 18                             улица Твардовского  11
# 6                             Строгинский бульвар   9
# 4                                Неманский проезд   8
# 7                               Строгинское шоссе   6
# 17                       улица Маршала Прошлякова   3
# 5                               Одинцовская улица   3
# 1   66-й километр Московской Кольцевой Автодороги   3
# 15                        улица Маршала Воробьёва   3
# 0   62-й километр Московской Кольцевой Автодороги   2
# 12                        проспект Маршала Жукова   2
# 11                            проезд без названия   2
# 10                       Улица Маршала Прошлякова   2
# ...
